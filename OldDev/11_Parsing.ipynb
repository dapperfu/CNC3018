# %%
import os
import sys
from time import sleep
from uuid import uuid4

import GCode
import GRBL
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# # GCode Parsing/Modification

# %%
gcode = "Shading3_unified_0002.gcode"

# %%
prog = GCode.GCode()
prog.load(gcode)

# %%
buffer = [l for l in prog.buffer if len(l)>0]

# %%
buffer
# Out:
# ['M05 S0',
#  'G90',
#  'G21',
#  'G1 F301',
#  'G1  X158.0747 Y43.5063',
#  'M04 S1',
#  'G4 P0',
#  'G1 F299.000000',
#  'G1  X155.4402 Y42.4151',
#  'G3 X154.7347 Y41.3591 I0.4374 J-1.0559',
#  'G3 X155.4402 Y40.8877 I0.5103 J0.',
#  'G1  X160.7844 Y43.1013',
#  'G2 X164.3314 Y43.8069 I3.5471 J-8.5634',
#  'G2 X164.4718 Y43.1013 I0. J-0.3667',
#  'G1  X155.4402 Y39.3603',
#  'G3 X154.7347 Y38.3044 I0.4374 J-1.0559',
#  'G3 X155.4402 Y37.8329 I0.5103 J0.',
#  'G1  X168.1592 Y43.1013',
#  'G2 X171.7062 Y43.8069 I3.5471 J-8.5634',
#  'G2 X171.8466 Y43.1013 I0. J-0.3667',
#  'G1  X155.4402 Y36.3056',
#  'G3 X154.7347 Y35.2496 I0.4374 J-1.0559',
#  'G3 X155.4402 Y34.7782 I0.5103 J0.',
#  'G1  X172.8202 Y41.9772',
#  'G2 X173.5258 Y41.5058 I0.1953 J-0.4714',
#  'G2 X172.8202 Y40.4499 I-1.1429 J0.',
#  'G1  X155.4402 Y33.2508',
#  'G3 X154.7347 Y32.1949 I0.4374 J-1.0559',
#  'G3 X155.4402 Y31.7234 I0.5103 J0.',
#  'G1  X172.8202 Y38.9225',
#  'G2 X173.5258 Y38.451 I0.1953 J-0.4714',
# ...

# %%
import re

# %%
import numpy as np

# %%
for l in buffer:
    if

# %%
GCode.GCode(gcode).buffer
# Out:
# []

# %%
cnc = GRBL.GRBL(port="/dev/cnc_3018")
sleep(0.5)
cnc.laser_mode = 1
sleep(0.5)
print("Laser Mode: {}".format(cnc.laser_mode))
# Out:
# ok
# Laser Mode: 1.0

# %%
cnc.status
# Out:
# '<Idle|MPos:-255.900,-136.000,-1.000|Bf:15,127|FS:0,0>'

# %%
cnc.home()
# Out:
# 14

# %%
def init():
    program = GCode.GCode()
    program.G0(F=500)
    program.G1(F=300)
    program.M3(S=1)
    program.G28()
    program.G21()  # Metric Units
    program.G90()  # Absolute positioning.
    program.G92(X=0, Y=0)
    program.M5()
    return program


def end():
    program = GCode.GCode()
    program.M5()
    program.G28()
    return program

# %%
import glob

# %%
# Merge multiple files for playback

# %%
shading=glob.glob("Shading2_*.gcode")
shading.sort()

# %%
shading
# Out:
# ['Shading2_0001.gcode',
#  'Shading2_0002.gcode',
#  'Shading2_0003.gcode',
#  'Shading2_0004.gcode']

# %%
full_prog = GCode.GCode(machine=cnc)
full_prog+=init()

for shade in shading:
    prog = GCode.GCode()
    prog.load(shade)
    full_prog+=prog
#
full_prog+=prog
full_prog+=end()

# %%
full_prog.run()

# %%
shading=glob.glob("Shading3_*.gcode")
shading.sort()
shading
# Out:
# ['Shading3_0001.gcode',
#  'Shading3_0002.gcode',
#  'Shading3_0003.gcode',
#  'Shading3_0004.gcode']

# %%
full_prog = GCode.GCode(machine=cnc)
full_prog+=init()

for shade in shading:
    prog = GCode.GCode()
    prog.load(shade)
    full_prog+=prog
#
full_prog+=prog
full_prog+=end()

# %%
full_prog.run()
