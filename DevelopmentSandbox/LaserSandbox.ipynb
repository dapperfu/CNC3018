# %% [markdown]
# # Laser Sandbox
# Loop over laser power settings and feed rate to determine how a given material looks.

# %% [markdown]
# # Code:

# %%
import GCode
import GRBL
import numpy as np
import os
import sys
from time import sleep

# %%
cnc = GRBL.GRBL(port="/dev/cnc_3018")
cnc.reset()
cnc.laser_mode = 1
# Out:
# ok

# %%
cnc.reset()
cnc.home()

# %%
cnc.cmd("M3S1")
cnc.cmd("G28")
# Out:
# []

# %%
cnc.cmd("G28")
# Out:
# ['ok', 'ok']

# %%
cnc.run(init())
# Out:
# 0.7274188995361328

# %%
p = GCode.GCode()
p.M4(S=150)
p.G1(X=179, Y=89, F=200)
p.G0(Y=0, F=500)
p.G1(X=0, Y=89, F=200)
p
# Out:
# <GCode>[cmds=4]

# %%
cnc.run(p)
# Out:
# 0.42113208770751953

# %%
sys.path.append(os.path.abspath(".."))

# %%
import utils

# %%
utils.picture()
