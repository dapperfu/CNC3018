# %% [markdown]
# # Figure out automating tests
#
# ## Object
# - Take pictures and insert into results programatically.

# %% [markdown]
# # Code:

# %%
# !streamer -o images/test.jpeg -s 1600x900
# Out:
# files / video: JPEG (JFIF) / audio: none
# fifo max fill: audio 0/0, video 1/16, convert 1/16

# %%
from IPython.display import *
import IPython.display

# %%
image = "images/test.jpeg"

# %%
display("images/test.jpeg")
# Out:
# 'images/test.jpeg'

# %%
display_jpeg("images/test.jpeg")

# %%
Image("images/test.jpeg")

# %%
Image("images/test.jpeg")
print("Hello")
# Out:
# Hello

# %%
display_jpeg(Image("images/test.jpeg"))

# %%
import datetime

# %%
import os

# %%
img_root = "images"
img_name = "{}.jpeg".format(datetime.datetime.now())

if not os.path.exists(img_root):
    os.makedirs(img_root)

# %%
img_path = os.path.join(img_root, img_name)

# %%
from subprocess import check_output

# %%
resolution = "1600x900"

# %%
cmd_array = ["streamer", "-s", resolution, "-o", img_path, ]
cmd_array
# Out:
# ['streamer', '-s', '1600x900', '-o', 'images/2017-08-29 14:32:59.360320.jpeg']

# %%
ret  = check_output(cmd_array)

# %%
display_jpeg(Image(img_path))

# %%
from subprocess import check_output

resolution = "1600x900"

def picture():
    img_root = "images"
    img_name = "{}.jpeg".format(datetime.datetime.now())

    if not os.path.exists(img_root):
        os.makedirs(img_root)
        
    img_path = os.path.join(img_root, img_name)

    cmd_array = ["streamer", "-s", resolution, "-o", img_path, ]
    cmd_array

    ret  = check_output(cmd_array)
    
    display_jpeg(Image(img_path))

# %%
picture()

# %%
# %%file utils.py

from subprocess import check_output

resolution = "1600x900"

def picture():
    img_root = "images"
    img_name = "{}.jpeg".format(datetime.datetime.now())

    if not os.path.exists(img_root):
        os.makedirs(img_root)
        
    img_path = os.path.join(img_root, img_name)

    cmd_array = ["streamer", "-s", resolution, "-o", img_path, ]
    cmd_array

    ret  = check_output(cmd_array)
    
    display_jpeg(Image(img_path))
# Out:
# Writing utils.py
