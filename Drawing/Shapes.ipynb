# %%
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np

import GCode
import GRBL

# %% [markdown]
# # Draw a Shapes
#
# Attempt at programmatically drawing shapes.
#
# All units in mm. ```1``` = ```1 mm```.

# %%
# Draw line from (0, 0) to (10, 0)
line_points = np.array([
    [0, 0],
    [10, 0],
])

# %%
class Program(object):
    def __init__(self, lines=list()):
        self.lines = lines


prog = Program(lines=lines)
prog.lines
# Out:
# [<GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9],
#  <GCode>[cmds=9]]

# %%
self = prog

# %%
class Square(GCode.Line):

# %%
self.lin

# %%
plt.xkcd()
plt.plot(X, Y)
# Out:
# /projects/CNC3018/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
for idx in range(1, len(line.points)):
    print(idx)
# Out:
# 1

# %%
(line.points[idx - 1][0], line.points[idx][0])
# Out:
# (0.0, 178.0)

# %%
(line.points[idx - 1][1], line.points[idx][1])
# Out:
# (17.8, 17.8)

# %%
for idx in range(1, len(line.points)):
    X = (line.points[idx - 1][0], line.points[idx][0])
    Y = (line.points[idx - 1][1], line.points[idx][1])
    plt.plot(X, Y)

# %%
default_triangle = GCode.Line()

# %%
default_triangle.points
# Out:
# array([[ 0.        ,  0.        ],
#        [17.32050808,  0.        ],
#        [17.32050808, 10.        ],
#        [ 0.        ,  0.        ]])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel("X Position (mm)")
ax.set_ylabel("Y Position (mm)")

current_pos = np.array([[0], [0]])

X = np.array([[current_pos[0]], [line.points[0][0]]])
Y = np.array([[current_pos[1]], [line.points[0][1]]])
plt.plot(X, Y, color="red", linestyle="dashed")

for idx in range(1, len(line.points)):
    X = (line.points[idx - 1][0], line.points[idx][0])
    Y = (line.points[idx - 1][1], line.points[idx][1])
    plt.plot(X, Y, color="blue")

plt.title()

# %%
default_triangle.points
# Out:
# array([[ 0.        ,  0.        ],
#        [17.32050808,  0.        ],
#        [17.32050808, 10.        ],
#        [ 0.        ,  0.        ]])

# %%
self = default_triangle

# %%
self.points[0]
# Out:
# array([0., 0.])

# %%
self.points[0][0]
# Out:
# 0.0
